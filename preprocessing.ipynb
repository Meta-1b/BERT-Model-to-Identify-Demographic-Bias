# %%
import numpy as np
import pandas as pd
import os

# %%
# going through each csv file and creating a corresponding dataframe
df_gender = pd.read_csv("data/reddit_comments_gender_female_processed_phrase_annotated.csv")
df_gender
# Out:
#       attribute_in_window                                            comment  \
# 0                    True  im sorry this is happening for you. at least y...
# 1                    True       their mothers are in on the joke art project
# 2                    True  i feel like this is some deep artistic dance t...
# 3                    True  or biology. over protective and smothering mot...
# 4                    True  writing poetry to a girl is the fastest way to...
# ...                   ...                                                ...
# 2995                 True  clean your fucking bathroom you beta-maid piec...
# 2996                 True  they fucked with the dubs of dragon maid and m...
# 2997                 True  its cause im at minute maid but my girlfriend ...
# 2998                 True  my profile. im a ft deli clerk and pay range i...
# 2999                 True  clerk trainer been here for.5 years. my girlfr...
#
# ...

# %%
df_orientation = pd.read_csv("data/reddit_comments_orientation_lgbtq_processed_phrase_annotated.csv")
df_orientation
# Out:
#       id  attribute_in_window  \
# 0    NaN                 True
# 1    NaN                 True
# 2    NaN                 True
# 3    NaN                 True
# 4    NaN                 True
# ...   ..                  ...
# 7988 NaN                 True
# 7989 NaN                 True
# 7990 NaN                 True
# 7991 NaN                 True
# 7992 NaN                 True
#
#                                                 comment  \
# 0     would it turn you on if i said that all gays a...
# 1               yeah except gay people are mentally ill
# 2                           gay people are mentally ill
# 3     wow gay people truly are mentally ill after al...
# 4     thats like saying gay people are mentally ill ...
# ...                                                 ...
# 7988                        pansexuals are pretty weird
# 7989                d ud e pansexuals are fucking weird
# 7990  why is there this weird exclusionary thing wit...
# ...

# %%
df_race = pd.read_csv("data/reddit_comments_race_black_processed_phrase_annotated.csv")
df_race
# Out:
#            id  attribute_in_window  \
# 0     fxlkyso                 True
# 1     fxdm2pg                 True
# 2     fxek9n6                 True
# 3     fv14wca                 True
# 4     fv37xgq                 True
# ...       ...                  ...
# 2995  dzp2h1c                 True
# 2996  dn0ezw7                 True
# 2997  dhfi80p                 True
# 2998  dqhoa7l                 True
# 2999  f0vu3ny                 True
#
#                                                 comment  \
# 0     so what does this video try to prove that mexi...
# 1     the statistic is about violent crimes or murde...
# 2     yep its totally because of melanine! that shit...
# 3     we are blaming the africans because the africa...
# 4     why .3? we agree that africans are violent and...
# ...                                                 ...
# 2995       as loud as black girls are neither can they.
# 2996  black girls are loud. i have an obnoxious laug...
# ...

# %%
df_religion2 = pd.read_csv("data/reddit_comments_religion2_muslims_processed_phrase_annotated.csv")
df_religion2
# Out:
#             id  attribute_in_window  \
# 0      fxqotw4                 True
# 1      fy1nhu8                False
# 2      fxqrpjr                 True
# 3      fyqyg0s                 True
# 4      fzb1uxf                 True
# ...        ...                  ...
# 10579  dlre79o                 True
# 10580  dlreadd                 True
# 10581  dlreflm                 True
# 10582  disuk3y                 True
# 10583  dj3vd8k                 True
#
#                                                  comment  \
# 0      its like the muslim people are terrorist or je...
# 1      muslim people are so kind. i should become a t...
# 2      now i know why the stereotype of all muslims a...
# 3      not all arabs are terrorists but all terrorist...
# 4      so youre just a racist that thinks all arabs a...
# ...                                                  ...
# 10579  false comparison not every muslim is violent. ...
# 10580  if every nazi is violent because they believe ...
# ...

# %%
df_religion1 = pd.read_csv("data/reddit_comments_religion1_jews_processed_phrase_annotated.csv")
df_religion1
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File parsers.pyx:1119, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1271, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1284, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1532, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 75: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_religion1 = pd.read_csv("data/reddit_comments_religion1_jews_processed_phrase_annotated.csv", encoding='utf-8')
#       2 df_religion1
#
# ...

# %%
df_gender.head()
# Out:
#    attribute_in_window                                            comment  \
# 0                 True  im sorry this is happening for you. at least y...
# 1                 True       their mothers are in on the joke art project
# 2                 True  i feel like this is some deep artistic dance t...
# 3                 True  or biology. over protective and smothering mot...
# 4                 True  writing poetry to a girl is the fastest way to...
#
#                                               phrase  bias_sent  bias_phrase  \
# 0  least you know whats happening now. narcissist...          0            0
# 1       their mothers are in on the joke art project          1            1
# 2  artistic dance thats trying to highlight how m...          0            0
# 3  or biology. over protective and smothering mot...          0            0
# 4  writing poetry to a girl is the fastest way to...          0            0
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# ...

# %%
df_gender['bias_phrase'] # this is the label
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2995    0
# 2996    0
# 2997    0
# 2998    1
# 2999    0
# Name: bias_phrase, Length: 3000, dtype: int64

# %%
# taking care of missing values
nan_detected = np.sum(df_gender.isnull(), axis=0)
nan_detected
# Out:
# attribute_in_window       0
# comment                   0
# phrase                    0
# bias_sent                 0
# bias_phrase               0
# Unnamed: 5             2999
# dtype: int64

# %%
# should we drop or find the average
# given that they are unamed, we can just drop
missing_columns = df_gender.columns[df_gender.isnull().any()].tolist()

# %%
missing_columns
# Out:
# ['Unnamed: 5']

# %%
df_gender = df_gender.drop(columns = missing_columns, axis = 0)

# %%
df_gender
# Out:
#       attribute_in_window                                            comment  \
# 0                    True  im sorry this is happening for you. at least y...
# 1                    True       their mothers are in on the joke art project
# 2                    True  i feel like this is some deep artistic dance t...
# 3                    True  or biology. over protective and smothering mot...
# 4                    True  writing poetry to a girl is the fastest way to...
# ...                   ...                                                ...
# 2995                 True  clean your fucking bathroom you beta-maid piec...
# 2996                 True  they fucked with the dubs of dragon maid and m...
# 2997                 True  its cause im at minute maid but my girlfriend ...
# 2998                 True  my profile. im a ft deli clerk and pay range i...
# 2999                 True  clerk trainer been here for.5 years. my girlfr...
#
# ...

# %%
# now doing the same for all the rest of the dataframes
df_orientation.head()
# Out:
#    id  attribute_in_window                                            comment  \
# 0 NaN                 True  would it turn you on if i said that all gays a...
# 1 NaN                 True            yeah except gay people are mentally ill
# 2 NaN                 True                        gay people are mentally ill
# 3 NaN                 True  wow gay people truly are mentally ill after al...
# 4 NaN                 True  thats like saying gay people are mentally ill ...
#
#                                               phrase  bias_sent  bias_phrase
# 0  you on if i said that all gays are mentally il...        0.0          0.0
# 1            yeah except gay people are mentally ill        1.0          1.0
# 2                        gay people are mentally ill        1.0          1.0
# 3    wow gay people truly are mentally ill after all        1.0          1.0
# 4  thats like saying gay people are mentally ill ...        NaN          NaN

# %%
# filling the missing values of bias_sent and bias_phrase with 0
df_orientation["bias_sent"] = df_orientation["bias_sent"].fillna(0)
df_orientation["bias_phrase"] = df_orientation["bias_phrase"].fillna(0)

# %%
df_orientation
# Out:
#       id  attribute_in_window  \
# 0    NaN                 True
# 1    NaN                 True
# 2    NaN                 True
# 3    NaN                 True
# 4    NaN                 True
# ...   ..                  ...
# 7988 NaN                 True
# 7989 NaN                 True
# 7990 NaN                 True
# 7991 NaN                 True
# 7992 NaN                 True
#
#                                                 comment  \
# 0     would it turn you on if i said that all gays a...
# 1               yeah except gay people are mentally ill
# 2                           gay people are mentally ill
# 3     wow gay people truly are mentally ill after al...
# 4     thats like saying gay people are mentally ill ...
# ...                                                 ...
# 7988                        pansexuals are pretty weird
# 7989                d ud e pansexuals are fucking weird
# 7990  why is there this weird exclusionary thing wit...
# ...

# %%
# now because the id section is just NaNs we can drop that too? (Unless the id is important in some way to the data frame)
df_orientation = df_orientation.drop(columns = ["id"], axis = 0)

# %%
df_orientation.head()
# Out:
#    attribute_in_window                                            comment  \
# 0                 True  would it turn you on if i said that all gays a...
# 1                 True            yeah except gay people are mentally ill
# 2                 True                        gay people are mentally ill
# 3                 True  wow gay people truly are mentally ill after al...
# 4                 True  thats like saying gay people are mentally ill ...
#
#                                               phrase  bias_sent  bias_phrase
# 0  you on if i said that all gays are mentally il...        0.0          0.0
# 1            yeah except gay people are mentally ill        1.0          1.0
# 2                        gay people are mentally ill        1.0          1.0
# 3    wow gay people truly are mentally ill after all        1.0          1.0
# 4  thats like saying gay people are mentally ill ...        0.0          0.0

# %%
# now race
df_race.head()
# Out:
#         id  attribute_in_window  \
# 0  fxlkyso                 True
# 1  fxdm2pg                 True
# 2  fxek9n6                 True
# 3  fv14wca                 True
# 4  fv37xgq                 True
#
#                                              comment  \
# 0  so what does this video try to prove that mexi...
# 1  the statistic is about violent crimes or murde...
# 2  yep its totally because of melanine! that shit...
# 3  we are blaming the africans because the africa...
# 4  why .3? we agree that africans are violent and...
#
#                                               phrase  bias_sent  bias_phrase
# 0  video try to prove that mexicans and african a...        0.0          0.0
# 1  violent crimes or murders both of which black ...        1.0          1.0
# 2  that shit causes so much violence! because bla...        0.0          1.0
# 3  we are blaming the africans because the africa...        1.0          1.0
# ...

# %%
nan_detected_race = np.sum(df_race.isnull(), axis=0)
nan_detected_race
# Out:
# id                       0
# attribute_in_window      0
# comment                  0
# phrase                   0
# bias_sent              380
# bias_phrase            380
# dtype: int64

# %%
# replacing missing values in bias_sent and bias_phrase like previously
df_race["bias_sent"] = df_race["bias_sent"].fillna(0)
df_race["bias_phrase"] = df_race["bias_phrase"].fillna(0)

# %%
nan_detected_race = np.sum(df_race.isnull(), axis=0)
nan_detected_race
# Out:
# id                     0
# attribute_in_window    0
# comment                0
# phrase                 0
# bias_sent              0
# bias_phrase            0
# dtype: int64

# %%
# now lastly religion2 (for now until I can get the religion1 working)
df_religion2
# Out:
#             id  attribute_in_window  \
# 0      fxqotw4                 True
# 1      fy1nhu8                False
# 2      fxqrpjr                 True
# 3      fyqyg0s                 True
# 4      fzb1uxf                 True
# ...        ...                  ...
# 10579  dlre79o                 True
# 10580  dlreadd                 True
# 10581  dlreflm                 True
# 10582  disuk3y                 True
# 10583  dj3vd8k                 True
#
#                                                  comment  \
# 0      its like the muslim people are terrorist or je...
# 1      muslim people are so kind. i should become a t...
# 2      now i know why the stereotype of all muslims a...
# 3      not all arabs are terrorists but all terrorist...
# 4      so youre just a racist that thinks all arabs a...
# ...                                                  ...
# 10579  false comparison not every muslim is violent. ...
# 10580  if every nazi is violent because they believe ...
# ...

# %%
nan_detected_religion = np.sum(df_religion2.isnull(), axis=0)
nan_detected_religion
# Out:
# id                        0
# attribute_in_window       0
# comment                   0
# phrase                    1
# bias_sent              8782
# bias_phrase            8783
# dtype: int64

# %%
# this seems to be a much larger datset
df_religion2["bias_sent"] = df_religion2["bias_sent"].fillna(0)
df_religion2["bias_phrase"] = df_religion2["bias_phrase"].fillna(0)

# %%
nan_detected_religion = np.sum(df_religion2.isnull(), axis=0)
nan_detected_religion
# Out:
# id                     0
# attribute_in_window    0
# comment                0
# phrase                 1
# bias_sent              0
# bias_phrase            0
# dtype: int64

# %%
df_religion2['phrase'] = df_religion2['phrase'].fillna('Unknown')

# %%
nan_detected_religion = np.sum(df_religion2.isnull(), axis=0)
nan_detected_religion
# Out:
# id                     0
# attribute_in_window    0
# comment                0
# phrase                 0
# bias_sent              0
# bias_phrase            0
# dtype: int64

# %%
# all missing values done (will include label encoding after approval)
